# %% [markdown]
# # 02 — Features and classical models
#
# TF-IDF + numeric + one-hot category, sentiment classifiers (Logistic Regression, Decision Tree, Random Forest), Ridge rating regression, metrics on a holdout split.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

import pandas as pd
from app import config
from scripts.train_and_export import load_and_prepare, train_classical, save_processed

df = load_and_prepare()
print(df.shape)
df.head(2)

# %%
save_processed(df)
train_classical(df)
print("Artifacts:", config.MODEL_1, config.MODEL_2, config.MODEL_3, config.MODEL_4)

# %%
import joblib
import pandas as pd

clf = joblib.load(config.MODEL_1)
sample = pd.DataFrame(
    [
        {
            "cleaned_text": "great cable fast charging",
            "review_word_count": 4,
            "vader_compound": 0.6,
            "discount_pct": 40.0,
            "price_drop_pct": 35.0,
            "rating_count_num": 1000.0,
            "category_primary": "Computers&Accessories",
        }
    ]
)
print("predict", clf.predict(sample))
